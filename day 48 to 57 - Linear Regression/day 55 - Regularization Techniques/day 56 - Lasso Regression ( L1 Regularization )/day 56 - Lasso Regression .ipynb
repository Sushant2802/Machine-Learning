# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import Lasso
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

plt.scatter(X, y)

from sklearn.linear_model import LinearRegression 

reg = LinearRegression()
reg.fit(X_train, y_train)

print("coef_ : ", reg.coef_)
print("intercept_ : ", reg.intercept_)
print("\n\n")
# Out:
# coef_ :  [27.60945962]
# intercept_ :  -1.0416851511878895

# %%
from sklearn.linear_model import Lasso

reg = Lasso(alpha=0.1)
reg.fit(X_train, y_train)

plt.figure(figsize=(12, 6))
plt.scatter(X, y)
plt.plot(X_test, reg.predict(X_test), color='r')


print("coef_ : ", reg.coef_)
print("intercept_ : ", reg.intercept_)
print("\n\n")
# Out:
# coef_ :  [27.48747189]
# intercept_ :  -1.036465733977564

# %%
alphas = [0, 1, 5, 10, 30]
plt.figure(figsize=(12, 6))
plt.scatter(X, y)

for i in alphas:
    L = Lasso(alpha=i)
    L.fit(X_train, y_train)
    plt.plot(X_test, L.predict(X_test), label='alpha={}'.format(i))

plt.legend()
plt.show()
# Out:
# C:\Users\susha\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\base.py:1474: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\susha\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\susha\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.154e+04, tolerance: 7.539e+00 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
X, y = make_regression(n_samples=100, n_features=5, n_informative=3, n_targets=1, noise=20, random_state=13)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


from sklearn.linear_model import LinearRegression 

reg = LinearRegression()
reg.fit(X_train, y_train)

print("coef_ : ", reg.coef_)
print("intercept_ : ", reg.intercept_)
print("\n\n")
# Out:
# coef_ :  [11.15934268 25.85956072 -2.33677405 88.32697003 -0.32549329]
# intercept_ :  -0.7308813038771067
