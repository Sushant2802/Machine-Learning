# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
X = df.iloc[:,:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# train data
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE : ", mean_absolute_error(y_test, y_pred))
# Out:
# MAE :  0.2884710931878175

# %%
print("MSE : ", mean_squared_error(y_test, y_pred))
# Out:
# MSE :  0.12129235313495527

# %%
print("RMSE : ", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE :  0.34827051717731616

# %%
print("R2 score : ", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 score :  0.780730147510384

# %%
# Adjusted R2 Score

X_test.shape
# Out:
# (40, 1)

# %%
print("Adjusted R2 Score : ", 1 - ((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 Score :  0.7749598882343415

# %%
new_df = df.copy()
new_df['random_feature'] = np.random.random(200)

new_df = new_df[['cgpa','random_feature', 'package']]
new_df.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.117172     3.26
# 1  5.12        0.316148     1.98
# 2  7.82        0.704893     3.25
# 3  7.42        0.636176     3.67
# 4  6.94        0.624467     3.57

# %%
plt.scatter(new_df['random_feature'], new_df['package'])
plt.xlabel('random_feature')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
X = new_df.iloc[:, :-1]
y = new_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 score : ", r2_score(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
# Out:
# R2 score :  0.780027806958496

# %%
print("Adjusted R2 Score : ", 1 - ((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 Score :  0.7742390650363512

# %%
new_df2 = df.copy()
new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq', 'package']]
new_df2.head()
# Out:
#    cgpa    iq  package
# 0  6.89  2.66     3.26
# 1  5.12  2.68     1.98
# 2  7.82  3.35     3.25
# 3  7.42  3.47     3.67
# 4  6.94  4.47     3.57

# %%
plt.scatter(new_df2['iq'], new_df2['package'])
plt.xlabel('random_feature')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
X = new_df2.iloc[:, :-1]
y = new_df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()
