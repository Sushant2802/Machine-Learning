# %%
# on built in data there is no need to preprocessing
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
# use linear regressin to check the values of intercept_ & coef_
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(' coef:', reg.coef_)
print('\n intercept:',reg.intercept_)
# Out:
#  coef: [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
#
#  intercept: 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %%
X_train.shape
# Out:
# (353, 10)

# %% [markdown]
# ## Using own class

# %%
class GDRegressor:

    def __init__(self, learning_rate=0.01, epochs=100):

        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X_train, y_train):
        # initial your coefficients
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])

        for i in range(self.epochs):
            # update all coef_ & intercept_
            y_hat = np.dot(X_train, self.coef_) + self.intercept_
            #print("shape : ",y_hat.shape)
            intercept_der = -2 * np.mean( y_train - y_hat )
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)

            coef_der = -2 * np.dot((y_train - y_hat), X_train)/X_train.shape[0]
            self.coef_ = self.coef_ - (self.lr * coef_der)
        print(self.intercept_, self.coef_)

    def predict(self, X_test):
        return np.dot(X_test, self.coef_)+ self.intercept_

# %%
gdr = GDRegressor(epochs=5000, learning_rate=0.5)

# %%
gdr.fit(X_train, y_train)
# Out:
# 151.9083716196347 [  -7.17899568 -200.89662377  534.44846913  338.77146751 -106.0752047
#   -85.59958426 -176.09688297   66.25305645  554.8160255    53.90871969]

# %%
y_pred = gdr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.44355681883598796

# %% [markdown]
# ## Using sk-learn

# %%
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import SGDRegressor


sgd_regressor = SGDRegressor(max_iter=1000, tol=1e-3, eta0=0.01, learning_rate='constant')

# %%
sgd_regressor.fit(X_train, y_train)
# Out:
# SGDRegressor(learning_rate='constant')

# %%
from sklearn.metrics import mean_squared_error

y_pred = sgd_regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 3130.796085881541

# %%
r2_score(y_test, y_pred)
# Out:
# 0.43335679061765764
